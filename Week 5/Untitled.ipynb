# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
years=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
population=[55.3,33.3,22.2,44.4,66.4,33.33,66.3,88.33,10.22,44.33]
x=np.random.uniform(population[0],population[9],10)
plt.plot(x)
plt.show()
